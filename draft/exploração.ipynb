# %%
import numpy as np
import pandas as pd
import plotly.express as px
import requests

# %%
endpoint_properties = "https://helsinki-openapi.nuuka.cloud/api/v1.0/Property/List"
response_properties = requests.get(endpoint_properties)
response_properties
# Out:
# <Response [200]>

# %%
response_properties.json()[5]
# Out:
# {'locationName': '1508 Monitoimitalo Puustelli',
#  'propertyName': '1508 Monitoimitalo Puustelli',
#  'propertyCode': '091-033-0232-0003, 091-033-0260-0001'}

# %%
counter = 0
size_of_data = 50
data_list = []
for item in response_properties.json():
    item_to_append = item['locationName'].split(',')[0]
    data_list.append(item_to_append)
    counter += 1
    if counter > size_of_data:
        break
data_list
# Out:
# ['1000 Hakaniemen kauppahalli',
#  '1001 Hietalahden kauppahalli',
#  '1002 Vanha kauppahalli',
#  '1037 Vuotalo',
#  '1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen',
#  '1508 Monitoimitalo Puustelli',
#  '1509 Lpk Karvikka ja rppk Lemmikki',
#  '1511 Pauligin huvila',
#  '1512 Malmin raitti 3',
#  '1513 Psykiatrinen poliklinikka',
#  '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#  '1521 Harjun NT (disabled)',
#  '1526 Annantalo',
#  '1527 Koskelan NT',
#  '1528 Apollon yhteiskoulu',
#  '1540 Virastotalo',
#  '1544 Lpk Linnunlaulu ja Lpk Arla',
#  '1546 Koulutuskeskus',
#  '1550 Fallkullan kartano/Kotieläintila',
#  '1556 Harakan luontokeskus',
#  '1561 Työterveyskeskus',
#  '1575 Nuorisoasiainkeskus',
#  '1580 Kruununmakasiini',
#  '1591 Etelä-Haagan kirjasto',
#  '1597 Lpk Lauttasaaren Ankkalampi (disabloitu)',
#  '1598 Jakomäen kirjasto',
#  '1603 Korttelitalo Merirasti',
#  '1608 Koskelan ala-aste /Lpk Herttua',
#  '1610 Laakavuoren korttelitalo/a-a/Lpk',
#  '1620 Tulli- ja pakkahuone',
#  '1621 Ravintola Kappeli ja lava',
#  '1627 Kurkimäen korttelitalo',
#  '1630 K 4',
#  '1637 Lp Kesanto',
#  '1644 Työväen asuntomuseo',
#  '1648 Kanneltalo',
#  '1650 Hoplaxskolan/Dh Sockenstugan',
#  '1652 Laajasalon kirj.NT ja Lpk Koulutanhua',
#  '1655 Lpk Virkkula',
#  '1668 Kyläsaarenkatu 8',
#  '1680 Vuosaaren telakka (disabled)',
#  '1686 Ruoholahden nuorisotalo Koralli',
#  '1689 Asunnottomien palvelukeskus (disabled)',
#  '1690 Oulunkylän seurahuone',
#  '1708 Pihlajamäen nuorisotalo',
#  '1713 Lasipalatsi Keskinäinen Koy (disabled)',
#  '1714 Linja-autoasema',
#  '1715 Raitiovaunumuseo',
#  '1716 Töölön virastotalo',
#  '1720 Rikhardinkadun kirjasto',
#  '1721 Lpk Aleksi  ja Dh Alexia']

# %%
building_list = []
endpoint_search = "https://helsinki-openapi.nuuka.cloud/api/v1.0/Property/Search"

for item in data_list:
    params_search = {
        'SearchFromRecord': 'locationName',
        'SearchString': item
    }
    response_search = requests.get(endpoint_search, params=params_search)
    building_list.append(response_search.json())
building_list
# Out:
# [[{'locationName': '1000 Hakaniemen kauppahalli',
#    'propertyName': '1000 Hakaniemen kauppahalli',
#    'propertyCode': '091-011-9902-0101',
#    'yearOfIntroduction': '1912-01-01T00:00:00',
#    'purposeOfUse': 'C kauppahalli',
#    'totalArea': 3669.0,
#    'heatedArea': 2542.0,
#    'volume': 18966.0,
#    'buildingType': 'ShoppingCenterMall',
#    'latitude': '60.1790792',
#    'longitude': '24.9512300',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1000 Hakaniemen kauppahalli, 2062 kauppahalli',
#      'propertyName': '1000 Hakaniemen kauppahalli',
#      'propertyCode': '091-011-9902-0101',
#      'buildingCode': '1031710103',
#      'yearOfIntroduction': '1912-01-01T00:00:00',
#      'purposeOfUse': 'C kauppahalli',
#      'totalArea': 3669.0,
#      'heatedArea': 2542.0,
#      'volume': 18966.0,
#      'buildingType': 'ShoppingCenterMall',
#      'longitude': '24.9513312',
#      'latitude': '60.1790452',
#      'reportingGroups': []}]}],
#  [{'locationName': '1001 Hietalahden kauppahalli',
#    'propertyName': '1001 Hietalahden kauppahalli',
#    'propertyCode': '091-004-9902-0008',
#    'yearOfIntroduction': '1904-01-01T00:00:00',
#    'purposeOfUse': 'C kauppahalli',
#    'totalArea': 1914.0,
#    'heatedArea': 1661.0,
#    'volume': 10017.0,
#    'buildingType': 'ShoppingCenterMall',
#    'latitude': '60.1627285',
#    'longitude': '24.9299523',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1001 Hietalahden kauppahalli,  528 kauppahalli',
#      'propertyName': '1001 Hietalahden kauppahalli',
#      'propertyCode': '091-004-9902-0008',
#      'buildingCode': '103075027V',
#      'yearOfIntroduction': '1904-01-01T00:00:00',
#      'purposeOfUse': 'C kauppahalli',
#      'totalArea': 1914.0,
#      'heatedArea': 1668.0,
#      'volume': 10017.0,
#      'buildingType': 'ShoppingCenterMall',
#      'longitude': '24.9299523',
#      'latitude': '60.1627285',
#      'reportingGroups': []}]}],
#  [{'locationName': '1002 Vanha kauppahalli',
#    'propertyName': '1002 Vanha kauppahalli',
#    'propertyCode': '091-003-9906-0101',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'C kauppahalli',
#    'totalArea': 1350.0,
#    'heatedArea': 1350.0,
#    'volume': 9115.0,
#    'buildingType': 'ShoppingCenterMall',
#    'latitude': '60.1658163',
#    'longitude': '24.9525547',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1002 Vanha kauppahalli,  410 kauppahalli',
#      'propertyName': '1002 Vanha kauppahalli',
#      'propertyCode': '091-003-9906-0101',
#      'buildingCode': '103055951H',
#      'yearOfIntroduction': '1890-01-01T00:00:00',
#      'purposeOfUse': 'C kauppahalli',
#      'totalArea': 1350.0,
#      'heatedArea': 1350.0,
#      'volume': 9115.0,
#      'buildingType': 'ShoppingCenterMall',
#      'longitude': '24.9525547',
#      'latitude': '60.1658163',
#      'reportingGroups': []}]}],
#  [{'locationName': '1037 Vuotalo',
#    'propertyName': '1037 Vuotalo',
#    'propertyCode': '091-054-0179-0003',
#    'yearOfIntroduction': '2001-01-01T00:00:00',
#    'purposeOfUse': 'G monitoimitalo',
#    'totalArea': 6426.0,
#    'heatedArea': 4643.9,
#    'volume': 32415.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2088024',
#    'longitude': '25.1433085',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1037 Vuotalo,  42390 Vuotalo',
#      'propertyName': '1037 Vuotalo',
#      'propertyCode': '091-054-0179-0003',
#      'buildingCode': '1023286761',
#      'yearOfIntroduction': '2001-01-01T00:00:00',
#      'purposeOfUse': 'G monitoimitalo',
#      'totalArea': 6426.0,
#      'heatedArea': 46439.0,
#      'volume': 32415.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '25.1433085',
#      'latitude': '60.2088024',
#      'reportingGroups': []}]}],
#  [{'locationName': '1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen',
#    'propertyName': '1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen',
#    'propertyCode': '091-040-0024-0003',
#    'yearOfIntroduction': '1981-01-01T00:00:00',
#    'purposeOfUse': 'G monitoimitalo',
#    'totalArea': 7354.0,
#    'heatedArea': 6150.9,
#    'volume': 33650.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2754845',
#    'longitude': '24.9974220',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen,  21715 monitoimitalo',
#      'propertyName': '1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen',
#      'propertyCode': '091-040-0024-0003',
#      'buildingCode': '1021839448',
#      'yearOfIntroduction': '1981-01-01T00:00:00',
#      'purposeOfUse': 'G monitoimitalo',
#      'totalArea': 7354.0,
#      'heatedArea': 5597.0,
#      'volume': 33650.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9974220',
#      'latitude': '60.2754845',
#      'reportingGroups': []}]}],
#  [{'locationName': '1508 Monitoimitalo Puustelli',
#    'propertyName': '1508 Monitoimitalo Puustelli',
#    'propertyCode': '091-033-0232-0003, 091-033-0260-0001',
#    'yearOfIntroduction': '1985-01-01T00:00:00',
#    'purposeOfUse': 'G monitoimitalo',
#    'totalArea': 4060.0,
#    'heatedArea': 3581.0,
#    'volume': 19900.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2461428',
#    'longitude': '24.8599921',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1508 Monitoimitalo Puustelli,  12204 monitoimitalo',
#      'propertyName': '1508 Monitoimitalo Puustelli',
#      'propertyCode': '091-033-0232-0003, 091-033-0260-0001',
#      'buildingCode': '100924340V',
#      'yearOfIntroduction': '1985-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 3815.0,
#      'heatedArea': 3468.0,
#      'volume': 19100.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.8599921',
#      'latitude': '60.2461428',
#      'reportingGroups': []},
#     {'locationName': '1508 Monitoimitalo Puustelli,  12205 Nuta',
#      'propertyName': '1508 Monitoimitalo Puustelli',
#      'propertyCode': '091-033-0232-0003, 091-033-0260-0001',
#      'buildingCode': '100924341W',
#      'yearOfIntroduction': '1985-01-01T00:00:00',
#      'purposeOfUse': 'A asuminen',
#      'totalArea': 245.0,
#      'heatedArea': 245.0,
#      'volume': 800.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.8599921',
#      'latitude': '60.2461428',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1509 Lpk Karvikka ja rppk Lemmikki',
#    'propertyName': '1509 Lpk Karvikka ja rppk Lemmikki',
#    'propertyCode': '091-038-0055-0010',
#    'yearOfIntroduction': '1980-01-01T00:00:00',
#    'purposeOfUse': 'F lasten päiväkoti',
#    'totalArea': 1468.0,
#    'heatedArea': 1216.5,
#    'volume': 5354.0,
#    'buildingType': 'Nursery',
#    'latitude': '60.2449607',
#    'longitude': '25.0077957',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1509 Lpk Karvikka ja rppk Lemmikki,  17127 lastenpäiväkoti',
#      'propertyName': '1509 Lpk Karvikka ja rppk Lemmikki',
#      'propertyCode': '091-038-0055-0010',
#      'buildingCode': '101466361D',
#      'yearOfIntroduction': '1980-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 1468.0,
#      'heatedArea': 889.0,
#      'volume': 5354.0,
#      'buildingType': 'Nursery',
#      'longitude': '25.0077957',
#      'latitude': '60.2449607',
#      'reportingGroups': []}]}],
#  [{'locationName': '1511 Pauligin huvila',
#    'propertyName': '1511 Pauligin huvila',
#    'propertyCode': '091-014-9903-0102',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 660.0,
#    'heatedArea': 529.0,
#    'volume': 1780.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.1800428',
#    'longitude': '24.9142782',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1511 Pauligin huvila,  3059 Pauligin huvila rak 001',
#      'propertyName': '1511 Pauligin huvila',
#      'propertyCode': '091-014-9903-0102',
#      'buildingCode': '103238448H',
#      'yearOfIntroduction': '1850-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 660.0,
#      'heatedArea': 529.0,
#      'volume': 1780.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9142782',
#      'latitude': '60.1800428',
#      'reportingGroups': []}]}],
#  [{'locationName': '1512 Malmin raitti 3',
#    'propertyName': '1512 Malmin raitti 3',
#    'propertyCode': '091-038-0107-0016',
#    'yearOfIntroduction': '1929-01-01T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 821.0,
#    'heatedArea': 542.0,
#    'volume': 2717.0,
#    'buildingType': 'Office',
#    'latitude': '60.2528222',
#    'longitude': '25.0081545',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1512 Malmin raitti 3,  37059 Rak 001',
#      'propertyName': '1512 Malmin raitti 3',
#      'propertyCode': '091-038-0107-0016',
#      'buildingCode': '101947870Y',
#      'yearOfIntroduction': '1929-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 821.0,
#      'heatedArea': 580.0,
#      'volume': 2717.0,
#      'buildingType': 'Office',
#      'longitude': '25.0081545',
#      'latitude': '60.2528222',
#      'reportingGroups': []}]}],
#  [{'locationName': '1513 Psykiatrinen poliklinikka',
#    'propertyName': '1513 Psykiatrinen poliklinikka',
#    'propertyCode': '091-022-0548-0043',
#    'yearOfIntroduction': '1958-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 3296.0,
#    'heatedArea': 2079.0,
#    'volume': 10793.0,
#    'buildingType': 'Office',
#    'latitude': '60.1934923',
#    'longitude': '24.9553642',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1513 Psykiatrinen poliklinikka,  4832 toimistorakennus',
#      'propertyName': '1513 Psykiatrinen poliklinikka',
#      'propertyCode': '091-022-0548-0043',
#      'buildingCode': '1032639184',
#      'yearOfIntroduction': '1958-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 3296.0,
#      'heatedArea': 0.0,
#      'volume': 10793.0,
#      'buildingType': 'Office',
#      'longitude': '24.9553642',
#      'latitude': '60.1934923',
#      'reportingGroups': []}]}],
#  [{'locationName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#    'propertyName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#    'propertyCode': '091-045-0138-0003',
#    'yearOfIntroduction': '1964-01-01T00:00:00',
#    'purposeOfUse': 'H ala-aste ja yläaste',
#    'totalArea': 3315.0,
#    'heatedArea': 2921.0,
#    'volume': 14433.0,
#    'buildingType': 'EducationalInstitution',
#    'latitude': '60.2227430',
#    'longitude': '25.0608393',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6,  27816 kouluviipale',
#      'propertyName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#      'propertyCode': '091-045-0138-0003',
#      'buildingCode': '101983630H',
#      'yearOfIntroduction': '1964-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 170.0,
#      'heatedArea': 0.0,
#      'volume': 560.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '25.0608393',
#      'latitude': '60.2227430',
#      'reportingGroups': []},
#     {'locationName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6,  27817 koulurakennus',
#      'propertyName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#      'propertyCode': '091-045-0138-0003',
#      'buildingCode': '101983631J',
#      'yearOfIntroduction': '1976-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 2012.0,
#      'heatedArea': 1754.0,
#      'volume': 9008.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '25.0608393',
#      'latitude': '60.2227430',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6,  27818 lastenpäiväkoti',
#      'propertyName': '1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6',
#      'propertyCode': '091-045-0138-0003',
#      'buildingCode': '101983632K',
#      'yearOfIntroduction': '1976-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 1133.0,
#      'heatedArea': 967.0,
#      'volume': 4865.0,
#      'buildingType': 'Nursery',
#      'longitude': '25.0608393',
#      'latitude': '60.2227430',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1521 Harjun NT (disabled)',
#    'propertyName': '1521 Harjun NT',
#    'propertyCode': '091-022-0366-0001',
#    'yearOfIntroduction': '1921-01-01T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 852.0,
#    'heatedArea': 645.0,
#    'volume': 2025.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.1897802',
#    'longitude': '24.9575028',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': []}],
#  [{'locationName': '1526 Annantalo',
#    'propertyName': '1526 Annantalo',
#    'propertyCode': '091-004-0001-0012',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'H ammattiopetus ja -korkeak.',
#    'totalArea': 4116.0,
#    'heatedArea': 2732.0,
#    'volume': 18148.0,
#    'buildingType': 'Office',
#    'latitude': '60.1678948',
#    'longitude': '24.9347896',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1526 Annantalo,  541 Annantalo',
#      'propertyName': '1526 Annantalo',
#      'propertyCode': '091-004-0001-0012',
#      'buildingCode': '103055959S',
#      'yearOfIntroduction': '1884-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 4116.0,
#      'heatedArea': 2732.0,
#      'volume': 18148.0,
#      'buildingType': 'Office',
#      'longitude': '24.9347896',
#      'latitude': '60.1678948',
#      'reportingGroups': []}]}],
#  [{'locationName': '1527 Koskelan NT',
#    'propertyName': '1527 Koskelan NT',
#    'propertyCode': '091-026-0975-0005',
#    'yearOfIntroduction': '1988-01-01T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 684.0,
#    'heatedArea': 608.0,
#    'volume': 2930.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2184162',
#    'longitude': '24.9670801',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1527 Koskelan NT,  6133 Nuta',
#      'propertyName': '1527 Koskelan NT',
#      'propertyCode': '091-026-0975-0005',
#      'buildingCode': '103349794A',
#      'yearOfIntroduction': '1988-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 684.0,
#      'heatedArea': 504.0,
#      'volume': 2930.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9670801',
#      'latitude': '60.2184162',
#      'reportingGroups': []}]}],
#  [{'locationName': '1528 Apollon yhteiskoulu',
#    'propertyName': '1528 Apollon yhteiskoulu',
#    'propertyCode': '091-033-0232-0002',
#    'yearOfIntroduction': '1985-01-01T00:00:00',
#    'purposeOfUse': 'H ala-aste ja yläaste',
#    'totalArea': 5510.0,
#    'heatedArea': 3859.0,
#    'volume': 26900.0,
#    'buildingType': 'EducationalInstitution',
#    'latitude': '60.2451653',
#    'longitude': '24.8559000',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1528 Apollon yhteiskoulu,  12202 koulu',
#      'propertyName': '1528 Apollon yhteiskoulu',
#      'propertyCode': '091-033-0232-0002',
#      'buildingCode': '100924338T',
#      'yearOfIntroduction': '1985-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 5510.0,
#      'heatedArea': 4385.0,
#      'volume': 26900.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '24.8559000',
#      'latitude': '60.2451653',
#      'reportingGroups': []}]}],
#  [{'locationName': '1540 Virastotalo, Dagmarinkatu 6 (disabled)',
#    'propertyName': '1540 Virastotalo, Dagmarinkatu 6',
#    'propertyCode': '091-013-0407-0010',
#    'yearOfIntroduction': '1924-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 3923.0,
#    'heatedArea': 2479.5,
#    'volume': 13320.0,
#    'buildingType': 'Office',
#    'latitude': '60.1735816',
#    'longitude': '24.9302933',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1540 Virastotalo, Dagmarinkatu 6,  2758 virastotalo',
#      'propertyName': '1540 Virastotalo, Dagmarinkatu 6',
#      'propertyCode': '091-013-0407-0010',
#      'buildingCode': '1031902270',
#      'yearOfIntroduction': '1924-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 3923.0,
#      'heatedArea': 2590.0,
#      'volume': 13320.0,
#      'buildingType': 'Office',
#      'longitude': '24.9302958',
#      'latitude': '60.1735793',
#      'reportingGroups': []}]}],
#  [{'locationName': '1544 Lpk Linnunlaulu ja Lpk Arla',
#    'propertyName': '1544 Lpk Linnunlaulu ja Lpk Arla',
#    'propertyCode': '091-011-9903-0111',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'F lasten päiväkoti',
#    'totalArea': 3112.0,
#    'heatedArea': 2105.0,
#    'volume': 12631.0,
#    'buildingType': 'Nursery',
#    'latitude': '60.1831346',
#    'longitude': '24.9394925',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1544 Lpk Linnunlaulu ja Lpk Arla,  2072 lastenpäiväkoti Rak 005',
#      'propertyName': '1544 Lpk Linnunlaulu ja Lpk Arla',
#      'propertyCode': '091-011-9903-0111',
#      'buildingCode': '1031710169',
#      'yearOfIntroduction': '1906-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 2469.0,
#      'heatedArea': 1630.0,
#      'volume': 10177.0,
#      'buildingType': 'Nursery',
#      'longitude': '24.9394925',
#      'latitude': '60.1831346',
#      'reportingGroups': []},
#     {'locationName': '1544 Lpk Linnunlaulu ja Lpk Arla,  2073 lastenpäiväkoti Rak 006',
#      'propertyName': '1544 Lpk Linnunlaulu ja Lpk Arla',
#      'propertyCode': '091-011-9903-0111',
#      'buildingCode': '103171017A',
#      'yearOfIntroduction': '1893-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 499.0,
#      'heatedArea': 0.0,
#      'volume': 1904.0,
#      'buildingType': 'Nursery',
#      'longitude': '24.9394925',
#      'latitude': '60.1831346',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1544 Lpk Linnunlaulu ja Lpk Arla,  2074 lastenpäiväkoti Tr 009',
#      'propertyName': '1544 Lpk Linnunlaulu ja Lpk Arla',
#      'propertyCode': '091-011-9903-0111',
#      'buildingCode': '103171018B',
#      'yearOfIntroduction': '2001-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 144.0,
#      'heatedArea': 140.0,
#      'volume': 550.0,
#      'buildingType': 'Nursery',
#      'longitude': '24.9394925',
#      'latitude': '60.1831346',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1546 Koulutuskeskus',
#    'propertyName': '1546 Koulutuskeskus',
#    'propertyCode': '091-011-0302-0007, 091-011-0302-0008',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 4552.0,
#    'heatedArea': 3965.0,
#    'volume': 18469.0,
#    'buildingType': 'EducationalInstitution',
#    'latitude': '60.1829978',
#    'longitude': '24.9419815',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1546 Koulutuskeskus,  2133 002 Koulutuskeskus',
#      'propertyName': '1546 Koulutuskeskus',
#      'propertyCode': '091-011-0302-0007, 091-011-0302-0008',
#      'buildingCode': '103151968U',
#      'yearOfIntroduction': '1898-01-01T00:00:00',
#      'purposeOfUse': 'H muu opetusrakennus',
#      'totalArea': 4452.0,
#      'heatedArea': 3250.0,
#      'volume': 18469.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '24.9419815',
#      'latitude': '60.1829978',
#      'reportingGroups': []},
#     {'locationName': '1546 Koulutuskeskus,  2134 001 ent. sokeain sauna',
#      'propertyName': '1546 Koulutuskeskus',
#      'propertyCode': '091-011-0302-0007, 091-011-0302-0008',
#      'buildingCode': '103151969V',
#      'yearOfIntroduction': '1898-01-01T00:00:00',
#      'purposeOfUse': 'H muu opetusrakennus',
#      'totalArea': 100.0,
#      'heatedArea': 715.0,
#      'volume': 0.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '24.9419815',
#      'latitude': '60.1829978',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1550 Fallkullan kartano/Kotieläintila',
#    'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#    'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'N maa- ja metsätalous',
#    'totalArea': 2734.0,
#    'heatedArea': 2543.5,
#    'volume': 8476.0,
#    'buildingType': 'OtherAgriculturalBuilding',
#    'latitude': '60.2573287',
#    'longitude': '25.0360974',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1550 Fallkullan kartano/Kotieläintila,  39044 007/puimala',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100232873F',
#      'yearOfIntroduction': '1920-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 715.0,
#      'heatedArea': 510.0,
#      'volume': 3210.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39045 008/kotieläintarha',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100232874H',
#      'yearOfIntroduction': '1870-01-01T00:00:00',
#      'purposeOfUse': 'N maa- ja metsätalous',
#      'totalArea': 744.0,
#      'heatedArea': 830.0,
#      'volume': 1800.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39046 010/ kalustos./kellari',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100232875J',
#      'yearOfIntroduction': '1956-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 400.0,
#      'heatedArea': 340.0,
#      'volume': 1300.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39047 012/ponitalli',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100232876K',
#      'yearOfIntroduction': '1930-01-01T00:00:00',
#      'purposeOfUse': 'N maa- ja metsätalous',
#      'totalArea': 30.0,
#      'heatedArea': 20.0,
#      'volume': 0.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39050 017/Ponitalli',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100232879N',
#      'yearOfIntroduction': '2001-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 30.0,
#      'heatedArea': 30.0,
#      'volume': 0.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39210 004/talousrakennus',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100242672K',
#      'yearOfIntroduction': '1920-01-01T00:00:00',
#      'purposeOfUse': 'C ravintola',
#      'totalArea': 250.0,
#      'heatedArea': 2085.0,
#      'volume': 0.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39221 025/fallkullan päärak.',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100242673L',
#      'yearOfIntroduction': '1880-01-01T00:00:00',
#      'purposeOfUse': 'A asuminen',
#      'totalArea': 340.0,
#      'heatedArea': 310.0,
#      'volume': 1725.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  39223 029/puutarh. as.rak.',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '100242674M',
#      'yearOfIntroduction': '1908-01-01T00:00:00',
#      'purposeOfUse': 'A asuminen',
#      'totalArea': 128.0,
#      'heatedArea': 44.0,
#      'volume': 352.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  999952 999/puuliiteri 3',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '',
#      'yearOfIntroduction': '1948-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 25.0,
#      'heatedArea': 25.0,
#      'volume': 89.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []},
#     {'locationName': '1550 Fallkullan kartano/Kotieläintila,  999954 998/talousrakennus',
#      'propertyName': '1550 Fallkullan kartano/Kotieläintila',
#      'propertyCode': '091-429-0001-0479, 091-429-0005-0270',
#      'buildingCode': '',
#      'yearOfIntroduction': '1920-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 72.0,
#      'heatedArea': 72.0,
#      'volume': 0.0,
#      'buildingType': 'OtherAgriculturalBuilding',
#      'longitude': '25.0360974',
#      'latitude': '60.2573287',
#      'reportingGroups': []}]}],
#  [{'locationName': '1556 Harakan luontokeskus',
#    'propertyName': '1556 Harakan luontokeskus',
#    'propertyCode': '091-432-0002-0000',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'N muu toimiala',
#    'totalArea': 2456.0,
#    'heatedArea': 2286.5,
#    'volume': 8986.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.1502114',
#    'longitude': '24.9538805',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1556 Harakan luontokeskus,  40700 Luontokeskus',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '102317375F',
#      'yearOfIntroduction': '1902-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 199.0,
#      'heatedArea': 165.0,
#      'volume': 796.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9571264',
#      'latitude': '60.1502114',
#      'reportingGroups': []},
#     {'locationName': '1556 Harakan luontokeskus,  40701 Talonmies',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '102317376H',
#      'yearOfIntroduction': '1906-01-01T00:00:00',
#      'purposeOfUse': 'A asuminen',
#      'totalArea': 155.0,
#      'heatedArea': 1125.0,
#      'volume': 543.0,
#      'buildingType': 'Dormitory',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  40702 Taidetalo',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '102317377J',
#      'yearOfIntroduction': '1928-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 1902.0,
#      'heatedArea': 1356.0,
#      'volume': 6974.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9571264',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  40703 Lennätinrakennus',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '102317378K',
#      'yearOfIntroduction': '1908-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 109.0,
#      'heatedArea': 55.0,
#      'volume': 381.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9571264',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  40704 kiinteistön huolto rak.',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '102317379L',
#      'yearOfIntroduction': '1992-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 29.0,
#      'heatedArea': 29.0,
#      'volume': 92.0,
#      'buildingType': 'MaintenanceDepartment',
#      'longitude': '24.9571264',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999946 lastentalo',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 0.0,
#      'heatedArea': 42.0,
#      'volume': 0.0,
#      'buildingType': 'Storage',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999947 Kasematti 3',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 0.0,
#      'heatedArea': 64.0,
#      'volume': 0.0,
#      'buildingType': 'Storage',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999948 Kasematti 4',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 0.0,
#      'heatedArea': 74.0,
#      'volume': 0.0,
#      'buildingType': 'IndustrialDistributionWarehouse',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999949 Kasematti 2',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 0.0,
#      'heatedArea': 73.0,
#      'volume': 0.0,
#      'buildingType': 'Storage',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999950 rantavaja',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 62.0,
#      'heatedArea': 61.0,
#      'volume': 200.0,
#      'buildingType': 'Storage',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1556 Harakan luontokeskus,  999951 Kasematti 1',
#      'propertyName': '1556 Harakan luontokeskus',
#      'propertyCode': '091-432-0002-0000',
#      'buildingCode': '',
#      'yearOfIntroduction': '1855-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 0.0,
#      'heatedArea': 79.0,
#      'volume': 0.0,
#      'buildingType': 'Storage',
#      'longitude': '24.9538805',
#      'latitude': '60.1502114',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1561 Työterveyskeskus',
#    'propertyName': '1561 Työterveyskeskus',
#    'propertyCode': '091-011-0326-0024',
#    'yearOfIntroduction': '1941-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 8621.0,
#    'heatedArea': 5804.0,
#    'volume': 32393.0,
#    'buildingType': 'HealthCare_HealthCenter',
#    'latitude': '60.1862363',
#    'longitude': '24.9503574',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1561 Työterveyskeskus,  2287 työterveyskeskus',
#      'propertyName': '1561 Työterveyskeskus',
#      'propertyCode': '091-011-0326-0024',
#      'buildingCode': '103161290J',
#      'yearOfIntroduction': '1941-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 8621.0,
#      'heatedArea': 5549.0,
#      'volume': 32393.0,
#      'buildingType': 'HealthCare_HealthCenter',
#      'longitude': '24.9503574',
#      'latitude': '60.1862363',
#      'reportingGroups': []}]}],
#  [{'locationName': '1575 Nuorisoasiainkeskus, Lpk Leppäsuo',
#    'propertyName': '1575 Nuorisoasiainkeskus, Lpk Leppäsuo',
#    'propertyCode': '091-013-0434-0002',
#    'yearOfIntroduction': '1976-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 6724.0,
#    'heatedArea': 5381.95,
#    'volume': 24515.0,
#    'buildingType': 'Office',
#    'latitude': '60.1701575',
#    'longitude': '24.9223703',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1575 Nuorisoasiainkeskus, Lpk Leppäsuo,  2926 virastotalo',
#      'propertyName': '1575 Nuorisoasiainkeskus, Lpk Leppäsuo',
#      'propertyCode': '091-013-0434-0002',
#      'buildingCode': '103199863U',
#      'yearOfIntroduction': '1976-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 6724.0,
#      'heatedArea': 4605.0,
#      'volume': 24515.0,
#      'buildingType': 'Office',
#      'longitude': '24.9223703',
#      'latitude': '60.1701575',
#      'reportingGroups': []}]}],
#  [{'locationName': '1580 Kruununmakasiini',
#    'propertyName': '1580 Kruununmakasiini',
#    'propertyCode': '091-410-0001-0004',
#    'yearOfIntroduction': '1900-01-01T00:00:00',
#    'purposeOfUse': 'K varasto',
#    'totalArea': 2256.0,
#    'heatedArea': 1990.0,
#    'volume': 7435.0,
#    'buildingType': 'Office',
#    'latitude': '60.1895866',
#    'longitude': '24.9645071',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1580 Kruununmakasiini,  35731 kruunumakasiini',
#      'propertyName': '1580 Kruununmakasiini',
#      'propertyCode': '091-410-0001-0004',
#      'buildingCode': '100889837V',
#      'yearOfIntroduction': '1900-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 2256.0,
#      'heatedArea': 1990.0,
#      'volume': 7435.0,
#      'buildingType': 'Office',
#      'longitude': '24.9645071',
#      'latitude': '60.1895866',
#      'reportingGroups': []}]}],
#  [{'locationName': '1591 Etelä-Haagan kirjasto, NT',
#    'propertyName': '1591 Etelä-Haagan kirjasto, NT',
#    'propertyCode': '091-029-0006-0004',
#    'yearOfIntroduction': '1964-01-01T00:00:00',
#    'purposeOfUse': 'G kirjasto',
#    'totalArea': 1195.0,
#    'heatedArea': 873.0,
#    'volume': 3580.0,
#    'buildingType': 'LibraryMuseumExhibitionHall',
#    'latitude': '60.2139534',
#    'longitude': '24.8914725',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1591 Etelä-Haagan kirjasto, NT,  7924 kirjasto',
#      'propertyName': '1591 Etelä-Haagan kirjasto, NT',
#      'propertyCode': '091-029-0006-0004',
#      'buildingCode': '1034342346',
#      'yearOfIntroduction': '1964-01-01T00:00:00',
#      'purposeOfUse': 'G kirjasto',
#      'totalArea': 1195.0,
#      'heatedArea': 795.0,
#      'volume': 3580.0,
#      'buildingType': 'LibraryMuseumExhibitionHall',
#      'longitude': '24.8914725',
#      'latitude': '60.2139534',
#      'reportingGroups': []}]}],
#  [{'locationName': '1597 Lpk Lauttasaaren Ankkalampi (disabloitu)',
#    'propertyName': '1597 Lpk Lauttasaaren Ankkalampi',
#    'propertyCode': '091-414-0001-0618',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'F lasten päiväkoti',
#    'totalArea': 310.0,
#    'heatedArea': 170.0,
#    'volume': 805.0,
#    'buildingType': 'Nursery',
#    'latitude': '60.1638008',
#    'longitude': '24.8809531',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': []}],
#  [{'locationName': '1598 Jakomäen kirjasto',
#    'propertyName': '1598 Jakomäen kirjasto',
#    'propertyCode': '091-041-0200-0010',
#    'yearOfIntroduction': '1981-01-01T00:00:00',
#    'purposeOfUse': 'G kirjasto',
#    'totalArea': 489.0,
#    'heatedArea': 424.0,
#    'volume': 2000.0,
#    'buildingType': 'LibraryMuseumExhibitionHall',
#    'latitude': '60.2604822',
#    'longitude': '25.0761862',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1598 Jakomäen kirjasto,  25054 kirjasto',
#      'propertyName': '1598 Jakomäen kirjasto',
#      'propertyCode': '091-041-0200-0010',
#      'buildingCode': '1031402594',
#      'yearOfIntroduction': '1981-01-01T00:00:00',
#      'purposeOfUse': 'G kirjasto',
#      'totalArea': 489.0,
#      'heatedArea': 446.0,
#      'volume': 2000.0,
#      'buildingType': 'LibraryMuseumExhibitionHall',
#      'longitude': '25.0761862',
#      'latitude': '60.2604822',
#      'reportingGroups': []}]}],
#  [{'locationName': '1603 Korttelitalo Merirasti',
#    'propertyName': '1603 Korttelitalo Merirasti',
#    'propertyCode': '091-054-0222-0002',
#    'yearOfIntroduction': '1993-01-01T00:00:00',
#    'purposeOfUse': 'G monitoimitalo',
#    'totalArea': 4942.0,
#    'heatedArea': 4452.0,
#    'volume': 22023.0,
#    'buildingType': 'EducationalInstitution',
#    'latitude': '60.2030334',
#    'longitude': '25.1190444',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1603 Korttelitalo Merirasti,  34184 korttelitalo 001',
#      'propertyName': '1603 Korttelitalo Merirasti',
#      'propertyCode': '091-054-0222-0002',
#      'buildingCode': '100095487N',
#      'yearOfIntroduction': '1993-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 4780.0,
#      'heatedArea': 4303.0,
#      'volume': 21501.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '25.1190444',
#      'latitude': '60.2030334',
#      'reportingGroups': []},
#     {'locationName': '1603 Korttelitalo Merirasti,  34185 korttelitalo 002',
#      'propertyName': '1603 Korttelitalo Merirasti',
#      'propertyCode': '091-054-0222-0002',
#      'buildingCode': '100095488P',
#      'yearOfIntroduction': '1993-01-01T00:00:00',
#      'purposeOfUse': 'H ala-aste ja yläaste',
#      'totalArea': 113.0,
#      'heatedArea': 96.0,
#      'volume': 394.0,
#      'buildingType': 'EducationalInstitution',
#      'longitude': '25.1190444',
#      'latitude': '60.2030334',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1603 Korttelitalo Merirasti,  34186 varastorakennus 003',
#      'propertyName': '1603 Korttelitalo Merirasti',
#      'propertyCode': '091-054-0222-0002',
#      'buildingCode': '100095489R',
#      'yearOfIntroduction': '1993-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 28.0,
# ...
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1668 Kyläsaarenkatu 8, Stara toimipiste,  4639 Rak 3, (D) kuivaamo',
#      'propertyName': '1668 Kyläsaarenkatu 8, Stara toimipiste',
#      'propertyCode': '091-021-0676-0003',
#      'buildingCode': '1032541833',
#      'yearOfIntroduction': '1978-01-01T00:00:00',
#      'purposeOfUse': 'J muu tuotanto/teollisuus',
#      'totalArea': 1194.0,
#      'heatedArea': 900.0,
#      'volume': 5467.0,
#      'buildingType': 'IndustrialManufacturing',
#      'longitude': '24.9727494',
#      'latitude': '60.1980231',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1668 Kyläsaarenkatu 8, Stara toimipiste,  4640 Rak 5, Kierrätyskeskus J',
#      'propertyName': '1668 Kyläsaarenkatu 8, Stara toimipiste',
#      'propertyCode': '091-021-0676-0003',
#      'buildingCode': '1032541844',
#      'yearOfIntroduction': '1970-01-01T00:00:00',
#      'purposeOfUse': 'J tukikohta',
#      'totalArea': 3760.0,
#      'heatedArea': 3894.0,
#      'volume': 10910.0,
#      'buildingType': 'IndustrialManufacturing',
#      'longitude': '24.9727494',
#      'latitude': '60.1980231',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1668 Kyläsaarenkatu 8, Stara toimipiste,  4641 tstokoppi',
#      'propertyName': '1668 Kyläsaarenkatu 8, Stara toimipiste',
#      'propertyCode': '091-021-0676-0003',
#      'buildingCode': '1032541855',
#      'yearOfIntroduction': '1980-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 37.0,
#      'heatedArea': 0.0,
#      'volume': 115.0,
#      'buildingType': 'Office',
#      'longitude': '24.9727494',
#      'latitude': '60.1980231',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1668 Kyläsaarenkatu 8, Stara toimipiste,  4643 Rak 8, Valvomo G',
#      'propertyName': '1668 Kyläsaarenkatu 8, Stara toimipiste',
#      'propertyCode': '091-021-0676-0003',
#      'buildingCode': '1032541877',
#      'yearOfIntroduction': '1975-01-01T00:00:00',
#      'purposeOfUse': 'J tukikohta',
#      'totalArea': 3203.0,
#      'heatedArea': 0.0,
#      'volume': 10910.0,
#      'buildingType': 'OtherBuilding',
#      'longitude': '24.9727494',
#      'latitude': '60.1980231',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]},
#     {'locationName': '1668 Kyläsaarenkatu 8, Stara toimipiste,  56286 Rak 481 sosiaalitilaparakki',
#      'propertyName': '1668 Kyläsaarenkatu 8, Stara toimipiste',
#      'propertyCode': '091-021-0676-0003',
#      'buildingCode': '103254204S',
#      'yearOfIntroduction': '2010-01-01T00:00:00',
#      'purposeOfUse': 'N muu toimiala',
#      'totalArea': 428.0,
#      'heatedArea': 395.0,
#      'volume': 1484.0,
#      'buildingType': 'OtherBuilding',
#      'longitude': '24.9727494',
#      'latitude': '60.1980231',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}],
#  [{'locationName': '1680 Vuosaaren telakka (disabled)',
#    'propertyName': '1680 Vuosaaren telakka',
#    'propertyCode': '091-054-0150-0001',
#    'yearOfIntroduction': '1974-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 3300.0,
#    'heatedArea': 2544.7,
#    'volume': 19630.0,
#    'buildingType': 'VocationalEducationalInstitution',
#    'latitude': '60.2108138',
#    'longitude': '25.1765343',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': []}],
#  [{'locationName': '1686 Ruoholahden nuorisotalo Koralli',
#    'propertyName': '1686 Ruoholahden nuorisotalo Koralli',
#    'propertyCode': '091-020-0255-0004',
#    'yearOfIntroduction': '1959-01-01T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 719.0,
#    'heatedArea': 570.0,
#    'volume': 2800.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.1599639',
#    'longitude': '24.9146382',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1686 Ruoholahden nuorisotalo Koralli,  4441 Nuta',
#      'propertyName': '1686 Ruoholahden nuorisotalo Koralli',
#      'propertyCode': '091-020-0255-0004',
#      'buildingCode': '1033039051',
#      'yearOfIntroduction': '1959-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 719.0,
#      'heatedArea': 590.0,
#      'volume': 2800.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9146382',
#      'latitude': '60.1599639',
#      'reportingGroups': []}]}],
#  [{'locationName': '1689 Asunnottomien palvelukeskus (disabled)',
#    'propertyName': '1689 Asunnottomien palvelukeskus',
#    'propertyCode': '091-013-0415-0003',
#    'yearOfIntroduction': '1907-01-01T00:00:00',
#    'purposeOfUse': 'C asuntola',
#    'totalArea': 3862.0,
#    'heatedArea': 3045.0,
#    'volume': 12825.0,
#    'buildingType': 'Office',
#    'latitude': '60.1700233',
#    'longitude': '24.9242702',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': []}],
#  [{'locationName': '1690 Oulunkylän seurahuone',
#    'propertyName': '1690 Oulunkylän seurahuone',
#    'propertyCode': '091-028-0007-0003',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 699.0,
#    'heatedArea': 512.6,
#    'volume': 2497.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2274395',
#    'longitude': '24.9690038',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1690 Oulunkylän seurahuone,  6313 seurahuone',
#      'propertyName': '1690 Oulunkylän seurahuone',
#      'propertyCode': '091-028-0007-0003',
#      'buildingCode': '103356881X',
#      'yearOfIntroduction': '1897-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 699.0,
#      'heatedArea': 515.0,
#      'volume': 2497.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '24.9690038',
#      'latitude': '60.2274395',
#      'reportingGroups': []}]}],
#  [{'locationName': '1708 Pihlajamäen nuorisotalo',
#    'propertyName': '1708 Pihlajamäen nuorisotalo',
#    'propertyCode': '091-038-0016-0007',
#    'yearOfIntroduction': '1992-01-01T00:00:00',
#    'purposeOfUse': 'G muu kokoontuminen',
#    'totalArea': 975.0,
#    'heatedArea': 820.0,
#    'volume': 3930.0,
#    'buildingType': 'OtherAssemblyBuilding',
#    'latitude': '60.2350852',
#    'longitude': '25.0116432',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1708 Pihlajamäen nuorisotalo,  16970 Nuta',
#      'propertyName': '1708 Pihlajamäen nuorisotalo',
#      'propertyCode': '091-038-0016-0007',
#      'buildingCode': '1014569616',
#      'yearOfIntroduction': '1992-01-01T00:00:00',
#      'purposeOfUse': 'G muu kokoontuminen',
#      'totalArea': 975.0,
#      'heatedArea': 820.0,
#      'volume': 3930.0,
#      'buildingType': 'OtherAssemblyBuilding',
#      'longitude': '25.0116432',
#      'latitude': '60.2350852',
#      'reportingGroups': []}]}],
#  [{'locationName': '1713 Lasipalatsi Keskinäinen Koy (disabled)',
#    'propertyName': '1713 Lasipalatsi Keskinäinen Koy',
#    'propertyCode': '091-004-0194-0001',
#    'yearOfIntroduction': '1935-01-01T00:00:00',
#    'purposeOfUse': 'C muu kauppa',
#    'totalArea': 5810.0,
#    'heatedArea': 4502.0,
#    'volume': 25603.0,
#    'buildingType': 'Office',
#    'latitude': '60.1690570',
#    'longitude': '24.9381954',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': []}],
#  [{'locationName': '1714 Linja-autoasema, Narikka (disabled)',
#    'propertyName': '1714 Linja-autoasema, Narikka',
#    'propertyCode': '091-004-0194-0001',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'C ravintola',
#    'totalArea': 2104.0,
#    'heatedArea': 1767.5,
#    'volume': 8469.0,
#    'buildingType': 'TransportationBuilding',
#    'latitude': '60.1696859',
#    'longitude': '24.9373686',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1714 Linja-autoasema, Narikka,  945 Linja-autoasema',
#      'propertyName': '1714 Linja-autoasema, Narikka',
#      'propertyCode': '091-004-0194-0001',
#      'buildingCode': '1030750066',
#      'yearOfIntroduction': '1833-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 2104.0,
#      'heatedArea': 1554.0,
#      'volume': 8469.0,
#      'buildingType': 'TransportationBuilding',
#      'longitude': '24.9378017',
#      'latitude': '60.1697861',
#      'reportingGroups': []}]}],
#  [{'locationName': '1715 Raitiovaunumuseo',
#    'propertyName': '1715 Raitiovaunumuseo',
#    'propertyCode': '091-014-0492-0011',
#    'yearOfIntroduction': '1900-01-01T00:00:00',
#    'purposeOfUse': 'G museo',
#    'totalArea': 1774.0,
#    'heatedArea': 1436.0,
#    'volume': 9559.0,
#    'buildingType': 'LibraryMuseumExhibitionHall',
#    'latitude': '60.1838707',
#    'longitude': '24.9224844',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1715 Raitiovaunumuseo,  3244 museo',
#      'propertyName': '1715 Raitiovaunumuseo',
#      'propertyCode': '091-014-0492-0011',
#      'buildingCode': '103219348C',
#      'yearOfIntroduction': '1900-01-01T00:00:00',
#      'purposeOfUse': 'G museo',
#      'totalArea': 1774.0,
#      'heatedArea': 15495.0,
#      'volume': 9559.0,
#      'buildingType': 'LibraryMuseumExhibitionHall',
#      'longitude': '24.9224844',
#      'latitude': '60.1838707',
#      'reportingGroups': []}]}],
#  [{'locationName': '1716 Töölön virastotalo',
#    'propertyName': '1716 Töölön virastotalo',
#    'propertyCode': '091-014-0508-0046',
#    'yearOfIntroduction': '1965-01-01T00:00:00',
#    'purposeOfUse': 'D toimisto',
#    'totalArea': 7850.0,
#    'heatedArea': 5790.0,
#    'volume': 28464.0,
#    'buildingType': 'Office',
#    'latitude': '60.1848420',
#    'longitude': '24.9156622',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1716 Töölön virastotalo,  3359 virastotalo',
#      'propertyName': '1716 Töölön virastotalo',
#      'propertyCode': '091-014-0508-0046',
#      'buildingCode': '1032290390',
#      'yearOfIntroduction': '1965-01-01T00:00:00',
#      'purposeOfUse': 'D toimisto',
#      'totalArea': 7850.0,
#      'heatedArea': 5790.0,
#      'volume': 28464.0,
#      'buildingType': 'Office',
#      'longitude': '24.9156622',
#      'latitude': '60.1848420',
#      'reportingGroups': []}]}],
#  [{'locationName': '1720 Rikhardinkadun kirjasto',
#    'propertyName': '1720 Rikhardinkadun kirjasto',
#    'propertyCode': '091-003-0049-0006',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'G kirjasto',
#    'totalArea': 2900.0,
#    'heatedArea': 2543.0,
#    'volume': 15766.0,
#    'buildingType': 'LibraryMuseumExhibitionHall',
#    'latitude': '60.1661552',
#    'longitude': '24.9463226',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1720 Rikhardinkadun kirjasto,  442 kirjasto',
#      'propertyName': '1720 Rikhardinkadun kirjasto',
#      'propertyCode': '091-003-0049-0006',
#      'buildingCode': '1030462397',
#      'yearOfIntroduction': '1882-01-01T00:00:00',
#      'purposeOfUse': 'G kirjasto',
#      'totalArea': 2900.0,
#      'heatedArea': 2373.0,
#      'volume': 15766.0,
#      'buildingType': 'LibraryMuseumExhibitionHall',
#      'longitude': '24.9463226',
#      'latitude': '60.1661552',
#      'reportingGroups': []}]}],
#  [{'locationName': '1721 Lpk Aleksi  ja Dh Alexia',
#    'propertyName': '1721 Lpk Aleksi  ja Dh Alexia',
#    'propertyCode': '091-001-0007-0001',
#    'yearOfIntroduction': '1899-12-31T00:00:00',
#    'purposeOfUse': 'F lasten päiväkoti',
#    'totalArea': 947.0,
#    'heatedArea': 681.0,
#    'volume': 3510.0,
#    'buildingType': 'Nursery',
#    'latitude': '60.1692800',
#    'longitude': '24.9576840',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#    'buildings': [{'locationName': '1721 Lpk Aleksi  ja Dh Alexia,  29 lastenpäiväkoti',
#      'propertyName': '1721 Lpk Aleksi  ja Dh Alexia',
#      'propertyCode': '091-001-0007-0001',
#      'buildingCode': '103017642R',
#      'yearOfIntroduction': '1820-01-01T00:00:00',
#      'purposeOfUse': 'F lasten päiväkoti',
#      'totalArea': 822.0,
#      'heatedArea': 681.0,
#      'volume': 3260.0,
#      'buildingType': 'Nursery',
#      'longitude': '24.9576840',
#      'latitude': '60.1692800',
#      'reportingGroups': []},
#     {'locationName': '1721 Lpk Aleksi  ja Dh Alexia,  31 lastenpäiväkoti',
#      'propertyName': '1721 Lpk Aleksi  ja Dh Alexia',
#      'propertyCode': '091-001-0007-0001',
#      'buildingCode': '',
#      'yearOfIntroduction': '1901-01-01T00:00:00',
#      'purposeOfUse': 'K varasto',
#      'totalArea': 125.0,
#      'heatedArea': 21.0,
#      'volume': 250.0,
#      'buildingType': 'Nursery',
#      'longitude': '24.9576840',
#      'latitude': '60.1692800',
#      'reportingGroups': [{'name': 'Electricity',
#        'energyType': 'Electricity',
#        'isTopGroup': True},
#       {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#       {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}]]

# %%
keys_to_search = ['locationName','yearOfIntroduction', 'purposeOfUse', 'totalArea', 'buildingType', 'reportingGroups']
# {key: value for key, value in building_list[0][0] if key in keys_to_search}
for item in building_list:
    
    for key, value in item[0].items():
        if key in keys_to_search:
            print(key,": ", value)
    print("")
# Out:
# locationName :  1000 Hakaniemen kauppahalli
# yearOfIntroduction :  1912-01-01T00:00:00
# purposeOfUse :  C kauppahalli
# totalArea :  3669.0
# buildingType :  ShoppingCenterMall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1001 Hietalahden kauppahalli
# yearOfIntroduction :  1904-01-01T00:00:00
# purposeOfUse :  C kauppahalli
# totalArea :  1914.0
# buildingType :  ShoppingCenterMall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1002 Vanha kauppahalli
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  C kauppahalli
# totalArea :  1350.0
# buildingType :  ShoppingCenterMall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1037 Vuotalo
# yearOfIntroduction :  2001-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  6426.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1507 Suutarilan monitoimitalo/ala-aste ja Lpk Seulanen
# yearOfIntroduction :  1981-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  7354.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1508 Monitoimitalo Puustelli
# yearOfIntroduction :  1985-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  4060.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1509 Lpk Karvikka ja rppk Lemmikki
# yearOfIntroduction :  1980-01-01T00:00:00
# purposeOfUse :  F lasten päiväkoti
# totalArea :  1468.0
# buildingType :  Nursery
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1511 Pauligin huvila
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  660.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1512 Malmin raitti 3
# yearOfIntroduction :  1929-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  821.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1513 Psykiatrinen poliklinikka
# yearOfIntroduction :  1958-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  3296.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1515 Myllypuron peruskoulu/Lpk Neulanen/Neulapadont. 6
# yearOfIntroduction :  1964-01-01T00:00:00
# purposeOfUse :  H ala-aste ja yläaste
# totalArea :  3315.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1521 Harjun NT (disabled)
# yearOfIntroduction :  1921-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  852.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1526 Annantalo
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  H ammattiopetus ja -korkeak.
# totalArea :  4116.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1527 Koskelan NT
# yearOfIntroduction :  1988-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  684.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1528 Apollon yhteiskoulu
# yearOfIntroduction :  1985-01-01T00:00:00
# purposeOfUse :  H ala-aste ja yläaste
# totalArea :  5510.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1540 Virastotalo, Dagmarinkatu 6 (disabled)
# yearOfIntroduction :  1924-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  3923.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1544 Lpk Linnunlaulu ja Lpk Arla
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  F lasten päiväkoti
# totalArea :  3112.0
# buildingType :  Nursery
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1546 Koulutuskeskus
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  4552.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1550 Fallkullan kartano/Kotieläintila
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  N maa- ja metsätalous
# totalArea :  2734.0
# buildingType :  OtherAgriculturalBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1556 Harakan luontokeskus
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  N muu toimiala
# totalArea :  2456.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1561 Työterveyskeskus
# yearOfIntroduction :  1941-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  8621.0
# buildingType :  HealthCare_HealthCenter
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1575 Nuorisoasiainkeskus, Lpk Leppäsuo
# yearOfIntroduction :  1976-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  6724.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1580 Kruununmakasiini
# yearOfIntroduction :  1900-01-01T00:00:00
# purposeOfUse :  K varasto
# totalArea :  2256.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1591 Etelä-Haagan kirjasto, NT
# yearOfIntroduction :  1964-01-01T00:00:00
# purposeOfUse :  G kirjasto
# totalArea :  1195.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1597 Lpk Lauttasaaren Ankkalampi (disabloitu)
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  F lasten päiväkoti
# totalArea :  310.0
# buildingType :  Nursery
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1598 Jakomäen kirjasto
# yearOfIntroduction :  1981-01-01T00:00:00
# purposeOfUse :  G kirjasto
# totalArea :  489.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1603 Korttelitalo Merirasti
# yearOfIntroduction :  1993-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  4942.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1608 Koskelan ala-aste /Lpk Herttua
# yearOfIntroduction :  1975-01-01T00:00:00
# purposeOfUse :  H ala-aste ja yläaste
# totalArea :  2304.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1610 Laakavuoren korttelitalo/a-a/Lpk
# yearOfIntroduction :  1990-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  4480.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1620 Tulli- ja pakkahuone, K 11
# yearOfIntroduction :  1901-01-01T00:00:00
# purposeOfUse :  K varasto
# totalArea :  6268.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1621 Ravintola Kappeli ja lava
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  C ravintola
# totalArea :  1536.0
# buildingType :  Restaurant
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1627 Kurkimäen korttelitalo, Lpk ja Lp
# yearOfIntroduction :  1988-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  2565.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1630 K 4, Elefanttikortteli
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  10538.0
# buildingType :  ShoppingCenterMall
# reportingGroups :  [{'name': 'DistrictCooling', 'energyType': 'DistrictCooling', 'isTopGroup': True}, {'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1637 Lp Kesanto
# yearOfIntroduction :  1913-01-01T00:00:00
# purposeOfUse :  F leikkipuisto
# totalArea :  338.0
# buildingType :  Dormitory
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1644 Työväen asuntomuseo
# yearOfIntroduction :  1908-01-01T00:00:00
# purposeOfUse :  G museo
# totalArea :  734.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1648 Kanneltalo, monitoimitalo
# yearOfIntroduction :  1992-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  5301.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1650 Hoplaxskolan/Dh Sockenstugan
# yearOfIntroduction :  1920-01-01T00:00:00
# purposeOfUse :  H ala-aste ja yläaste
# totalArea :  1586.0
# buildingType :  EducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1652 Laajasalon kirj.NT ja Lpk Koulutanhua,Rppk Nuppula (disabled)
# yearOfIntroduction :  1976-01-01T00:00:00
# purposeOfUse :  G monitoimitalo
# totalArea :  1250.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1655 Lpk Virkkula, Ruiskumestarin talo
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  F lasten päiväkoti
# totalArea :  635.0
# buildingType :  Nursery
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1668 Kyläsaarenkatu 8, Stara toimipiste
# yearOfIntroduction :  1970-01-01T00:00:00
# purposeOfUse :  J tukikohta
# totalArea :  14705.0
# buildingType :  OtherBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1680 Vuosaaren telakka (disabled)
# yearOfIntroduction :  1974-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  3300.0
# buildingType :  VocationalEducationalInstitution
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1686 Ruoholahden nuorisotalo Koralli
# yearOfIntroduction :  1959-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  719.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1689 Asunnottomien palvelukeskus (disabled)
# yearOfIntroduction :  1907-01-01T00:00:00
# purposeOfUse :  C asuntola
# totalArea :  3862.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1690 Oulunkylän seurahuone
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  699.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1708 Pihlajamäen nuorisotalo
# yearOfIntroduction :  1992-01-01T00:00:00
# purposeOfUse :  G muu kokoontuminen
# totalArea :  975.0
# buildingType :  OtherAssemblyBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'OtherMeasurements', 'energyType': '', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1713 Lasipalatsi Keskinäinen Koy (disabled)
# yearOfIntroduction :  1935-01-01T00:00:00
# purposeOfUse :  C muu kauppa
# totalArea :  5810.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1714 Linja-autoasema, Narikka (disabled)
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  C ravintola
# totalArea :  2104.0
# buildingType :  TransportationBuilding
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1715 Raitiovaunumuseo
# yearOfIntroduction :  1900-01-01T00:00:00
# purposeOfUse :  G museo
# totalArea :  1774.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1716 Töölön virastotalo
# yearOfIntroduction :  1965-01-01T00:00:00
# purposeOfUse :  D toimisto
# totalArea :  7850.0
# buildingType :  Office
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1720 Rikhardinkadun kirjasto
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  G kirjasto
# totalArea :  2900.0
# buildingType :  LibraryMuseumExhibitionHall
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]
#
# locationName :  1721 Lpk Aleksi  ja Dh Alexia
# yearOfIntroduction :  1899-12-31T00:00:00
# purposeOfUse :  F lasten päiväkoti
# totalArea :  947.0
# buildingType :  Nursery
# reportingGroups :  [{'name': 'Electricity', 'energyType': 'Electricity', 'isTopGroup': True}, {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True}, {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]

# %% [markdown]
# ## Trabalhando com 1 item

# %%
if building_list[14][0]['locationName'] == '1528 Apollon yhteiskoulu':
    print('deu certo')

# %%
location_name = '1610 Laakavuoren korttelitalo/a-a/Lpk'

def get_item_by_location (building_list, location):
    for item in building_list:
        if item[0]['locationName'] == location:
            return item[0]
        

building = get_item_by_location(building_list, location_name)
building
# Out:
# {'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#  'propertyName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#  'propertyCode': '091-047-0330-0001',
#  'yearOfIntroduction': '1990-01-01T00:00:00',
#  'purposeOfUse': 'G monitoimitalo',
#  'totalArea': 4480.0,
#  'heatedArea': 4039.0,
#  'volume': 20910.0,
#  'buildingType': 'EducationalInstitution',
#  'latitude': '60.2393260',
#  'longitude': '25.1098717',
#  'reportingGroups': [{'name': 'Electricity',
#    'energyType': 'Electricity',
#    'isTopGroup': True},
#   {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#   {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}],
#  'buildings': [{'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk,  31829 koulurakennus',
#    'propertyName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#    'propertyCode': '091-047-0330-0001',
#    'buildingCode': '102129341V',
#    'yearOfIntroduction': '1990-01-01T00:00:00',
#    'purposeOfUse': 'H ala-aste ja yläaste',
#    'totalArea': 4392.0,
#    'heatedArea': 2902.0,
#    'volume': 20630.0,
#    'buildingType': 'EducationalInstitution',
#    'longitude': '25.1098717',
#    'latitude': '60.2393260',
#    'reportingGroups': []},
#   {'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk,  31830 lastenpäiväkoti',
#    'propertyName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#    'propertyCode': '091-047-0330-0001',
#    'buildingCode': '102129342W',
#    'yearOfIntroduction': '1990-01-01T00:00:00',
#    'purposeOfUse': 'F lasten päiväkoti',
#    'totalArea': 88.0,
#    'heatedArea': 76.0,
#    'volume': 280.0,
#    'buildingType': 'Nursery',
#    'longitude': '25.1098717',
#    'latitude': '60.2393260',
#    'reportingGroups': [{'name': 'Electricity',
#      'energyType': 'Electricity',
#      'isTopGroup': True},
#     {'name': 'Heat', 'energyType': 'Heating', 'isTopGroup': True},
#     {'name': 'Water', 'energyType': 'Water', 'isTopGroup': True}]}]}

# %%
params_energy = {
    'Record': 'locationName',
    'SearchString': location_name,
    'ReportingGroup': 'Electricity',
    'StartTime': '2020-01-01',
    'EndTime': '2022-08-01',
}
endpoint_energy = "https://helsinki-openapi.nuuka.cloud/api/v1/EnergyData/Daily/ListByProperty"
response_energy = requests.get(endpoint_energy, params=params_energy)
response_energy.json()
# Out:
# [{'timestamp': '2020-01-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 879.3000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 922.5000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 930.3699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 428.51000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 215.30000000000007,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 850.58,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1208.3400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1256.95,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1183.79,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1163.8899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 414.18,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 228.35999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1177.4399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1202.9099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1261.2599999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1245.93,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1204.2000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 677.9099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 226.28999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1174.9699999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1193.07,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1212.21,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1180.4899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1176.54,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 430.71,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 227.04999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1187.9399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1202.64,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1241.47,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1201.63,
#   'unit': 'kWh'},
#  {'timestamp': '2020-01-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1159.21,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 419.18,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 215.04999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1163.65,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1156.23,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1182.4,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1146.5900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1170.8899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 442.44000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 217.67999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1174.21,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1159.67,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1206.9199999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1201.6699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1176.0799999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 431.06999999999994,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 225.16,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1051.63,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1012.53,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1066.8600000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1082.95,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1098.9700000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 495.97999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 288.49,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1178.1699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1153.8,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1139.7500000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1166.6900000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1118.3099999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-02-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 408.00999999999993,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 204.93999999999994,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1213.2600000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1204.4000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1251.0099999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1185.3000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1153.22,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 391.5300000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 199.37000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1151.4300000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1142.88,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1196.75,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1226.16,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1080.6699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 389.53,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 195.63000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1102.2900000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1038.2600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1068.6800000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 986.4799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 979.8100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 392.34,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 200.50000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 974.3300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 968.9999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 989.9100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1016.4000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1023.7499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 400.5899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 182.82999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 988.3500000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-03-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1003.4,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1022.69,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1026.3599999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1008.7799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 397.67999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 186.94,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1015.78,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1044.5600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1050.9800000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 982.7299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 859.6,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 162.89,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 196.47,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 840.8100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1071.31,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1072.79,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1033.1299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 989.4000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 167.8,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 191.19999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 986.35,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1020.07,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1043.29,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1008.6600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1046.8799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 180.09000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 204.27000000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1003.0600000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1027.2499999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1041.4,
#   'unit': 'kWh'},
#  {'timestamp': '2020-04-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1019.5200000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 857.7999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 164.69000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 189.20000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1028.8899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1060.89,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1010.8,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 976.5999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 976.4599999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 161.78000000000006,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 185.42000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1034.2299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1032.39,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1073.9300000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1093.2800000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1147.0900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 166.45999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 185.05,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1100.0299999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1127.95,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1146.5900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 854.01,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1078.19,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 160.05000000000007,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 182.81999999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1119.4799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1141.68,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1120.3599999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1110.75,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1068.3400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 330.99000000000007,
#   'unit': 'kWh'},
#  {'timestamp': '2020-05-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 175.61,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1002.3799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1000.6400000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 996.4600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 980.95,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 960.43,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 171.73000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 198.79000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 950.1699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 919.73,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 969.48,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 948.21,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 948.0400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 153.23,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 176.66000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 938.5799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 929.89,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 978.8200000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1015.8100000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 840.2700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 165.76999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 189.93,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 968.0400000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 969.9800000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 984.1400000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 953.4399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 983.74,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 170.65999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 193.98999999999992,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 949.7,
#   'unit': 'kWh'},
#  {'timestamp': '2020-06-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 999.1599999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 970.5500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 959.0299999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 948.85,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 154.13,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 180.8,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 912.4299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 925.69,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 934.5500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 922.88,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 956.5600000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 160.42000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 178.98999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 938.43,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 910.5700000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 939.72,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 893.6800000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 929.64,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 151.57999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 176.74,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 904.6,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 904.6799999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 944.9999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 911.4499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 943.2,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 154.95999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 177.79,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 901.6099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 973.6699999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 973.3199999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 907.7900000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-07-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 924.73,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 157.95999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 181.54999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 978.2400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 963.78,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 981.4499999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 998.1,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 992.1800000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 157.24,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 182.1,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1006.6500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1153.0100000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1155.9400000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1161.3899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1135.7199999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 167.52,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 191.64999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1124.6100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1152.7899999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1174.67,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1164.1399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1103.45,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 174.93,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 196.73000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1160.67,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1229.9399999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1236.58,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1195.41,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1146.62,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 183.64000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 211.30000000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2020-08-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1211.56,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1168.4600000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1198.05,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1201.1299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1186.04,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 178.57000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 198.48999999999995,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1126.7899999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1184.05,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1208.4199999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1193.03,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1159.3700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 181.59,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 199.17000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1144.5199999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1195.2500000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1185.4899999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1249.39,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1134.82,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 211.82,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 236.66000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1173.5599999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1188.29,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1206.7,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1131.6899999999996,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1127.21,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 199.87000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 227.96999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2020-09-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1172.7899999999995,
# ...
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1018.5099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 828.76,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 877.41,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 872.9399999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 847.7900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 179.01,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 179.22,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 881.9599999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1057.22,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1079.11,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1061.3799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1023.27,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 203.27,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 201.11,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1067.18,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1051.8300000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1043.8500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1052.2700000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1023.9399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 182.77999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 182.67,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1061.8300000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1023.6399999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1000.8099999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 770.6500000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1028.54,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 167.2,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 164.77,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 984.9399999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2022-05-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1060.03,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 986.35,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 1027.08,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 979.6999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 216.93,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 193.98000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 870.6899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 831.7299999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 856.6899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 841.8899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 820.6000000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 160.84999999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 158.65,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 811.3599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 825.1899999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 864.02,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 813.6699999999997,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 815.42,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 168.03,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 171.07999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 828.9099999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 843.4,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 823.3900000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 792.79,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 733.61,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 174.77000000000004,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 177.31000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 728.5100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 725.8,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 736.46,
#   'unit': 'kWh'},
#  {'timestamp': '2022-06-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 719.45,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-01T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 728.77,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-02T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 201.04000000000005,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-03T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 185.31000000000003,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-04T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 761.7699999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-05T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 721.2700000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-06T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 753.5999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-07T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 699.2199999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-08T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 770.3,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-09T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 160.8,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-10T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 160.73,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-11T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 678.98,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-12T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 779.0799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-13T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 808.8299999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-14T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 775.35,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-15T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 797.8400000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-16T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 158.57999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-17T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 158.20999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-18T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 660.15,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-19T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 747.53,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-20T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 760.5999999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-21T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 747.69,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-22T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 743.57,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-23T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 168.26999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-24T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 167.16,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-25T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 753.7999999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-26T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 762.2199999999998,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-27T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 786.8599999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-28T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 775.6100000000001,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-29T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 769.8799999999999,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-30T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 176.20000000000002,
#   'unit': 'kWh'},
#  {'timestamp': '2022-07-31T00:00:00',
#   'reportingGroup': 'Electricity',
#   'locationName': '1610 Laakavuoren korttelitalo/a-a/Lpk',
#   'value': 176.91000000000003,
#   'unit': 'kWh'}]

# %%
df = pd.DataFrame.from_dict(response_energy.json())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       942 non-null    object
#  1   reportingGroup  942 non-null    object
#  2   locationName    942 non-null    object
#  3   value           942 non-null    float64
#  4   unit            942 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 36.9+ KB

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       942 non-null    datetime64[ns]
#  1   reportingGroup  942 non-null    object
#  2   locationName    942 non-null    object
#  3   value           942 non-null    float64
#  4   unit            942 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 36.9+ KB

# %%
fig = px.line(df, x='timestamp', y='value')
fig.show()
